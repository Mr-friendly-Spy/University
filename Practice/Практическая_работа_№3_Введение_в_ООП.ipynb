# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-friendly-Spy/University/blob/main/Practice/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963_%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D0%9E%D0%9E%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
import math

class Sphere:
    def __init__(self, *args):
        if len(args) == 0:  # без аргументов
            self.radius = 1.0
            self.center = (0.0, 0.0, 0.0)
        elif len(args) == 1:  # только радиус
            self.radius = float(args[0])
            self.center = (0.0, 0.0, 0.0)
        elif len(args) == 4:  # радиус и 3 координаты
            self.radius = float(args[0])
            self.center = (float(args[1]), float(args[2]), float(args[3]))

    def get_volume(self):
        return (4/3) * math.pi * (self.radius ** 3)

    def get_square(self):
        return 4 * math.pi * (self.radius ** 2)

    def get_radius(self):
        return self.radius

    def get_center(self):
        return self.center

    def set_radius(self, r):
        self.radius = float(r)

    def set_center(self, x, y, z):
        self.center = (float(x), float(y), float(z))

    def is_point_inside(self, x, y, z):
        # Вычисляем квадрат расстояния от точки до центра сферы
        distance_squared = (x - self.center[0])**2 + \
                          (y - self.center[1])**2 + \
                          (z - self.center[2])**2
        # Точка внутри, если расстояние меньше или равно радиусу
        return distance_squared <= (self.radius ** 2)

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6
# Out:
# (0.0, 0.0, 0.0)
# 0.5235987755982988
# False
# True
# 1.6

# %%
# Ваш код

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):
    def is_repeatance(self, s):
        """
        Проверяет, можно ли получить текущую строку целым количеством повторов строки s.
        Возвращает False, если s не является строкой или если строка пустая.
        """
        # Проверяем, является ли s строкой
        if not isinstance(s, str):
            return False

        # Проверяем, не пустая ли строка s
        if len(s) == 0:
            return False

        # Проверяем, делится ли длина текущей строки на длину s
        current_len = len(self)
        pattern_len = len(s)

        if current_len % pattern_len != 0:
            return False

        # Проверяем, состоит ли строка из повторений s
        repeats = current_len // pattern_len
        expected_string = s * repeats

        return self == expected_string

    def is_palindrom(self):
        """
        Проверяет, является ли строка палиндромом.
        Регистр символов игнорируется, пустая строка считается палиндромом.
        """
        # Приводим строку к нижнему регистру для игнорирования регистра
        normalized = self.lower()

        # Сравниваем строку с её обратным вариантом
        return normalized == normalized[::-1]

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True
# Out:
# True
# True
# True
# False
# False
# False
# 123123123123
# 123123123123
# 123123123123qwe
# True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if (isinstance(lecturer, Lecturer) and
            course in lecturer.courses_attached and
            course in self.courses_in_progress and
            1 <= grade <= 10):
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        courses_in_progress_str = ', '.join(self.courses_in_progress)
        finished_courses_str = ', '.join(self.finished_courses)
        avg_grade = self.average_grade()
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress_str}\n"
                f"Завершенные курсы: {finished_courses_str}")

    def __lt__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.average_grade() < other.average_grade()


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {avg_grade:.1f}"

    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.average_grade() < other.average_grade()


class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)

    def rate_hw(self, student, course, grade):
        if (isinstance(student, Student) and
            course in self.courses_attached and
            course in student.courses_in_progress and
            1 <= grade <= 10):
            if course in student.grades:
                student.grades[course].append(grade)
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"


# Функция для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса
def average_hw_grade_for_course(students, course_name):
    total_grades = []
    for student in students:
        if course_name in student.grades:
            total_grades.extend(student.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0


# Функция для подсчета средней оценки за лекции всех лекторов в рамках курса
def average_lecture_grade_for_course(lecturers, course_name):
    total_grades = []
    for lecturer in lecturers:
        if course_name in lecturer.grades:
            total_grades.extend(lecturer.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0

# %%
# Тесты
print("=== Тестовая часть ===")

# Создание объектов
best_student = Student('Ruoy', 'Eman', 'male')
best_student.courses_in_progress = ['Python', 'Git']

cool_lecturer = Lecturer('John', 'Doe')
cool_lecturer.courses_attached = ['Python', 'Git']

cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached = ['Python', 'Git']

# Проверка методов
print("1. Тест базового функционала:")
cool_reviewer.rate_hw(best_student, 'Python', 9)
cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 8)
print("Оценки студента:", best_student.grades)

best_student.rate_lecturer(cool_lecturer, 'Python', 9)
best_student.rate_lecturer(cool_lecturer, 'Python', 10)
best_student.rate_lecturer(cool_lecturer, 'Python', 8)
print("Оценки лектора:", cool_lecturer.grades)

print("\n2. Тест магических методов __str__:")
print("Студент:")
print(best_student)
print("\nЛектор:")
print(cool_lecturer)
print("\nПроверяющий:")
print(cool_reviewer)

print("\n3. Тест сравнения объектов:")

# Создаем еще студентов для сравнения
student1 = Student('Alice', 'Smith', 'female')
student1.courses_in_progress = ['Python']
student1.grades = {'Python': [8, 9, 7]}

student2 = Student('Bob', 'Johnson', 'male')
student2.courses_in_progress = ['Python']
student2.grades = {'Python': [10, 9, 10]}

# Создаем еще лекторов для сравнения
lecturer1 = Lecturer('Keanu', ' Reeves')
lecturer1.grades = {'Python': [8, 9, 8]}

lecturer2 = Lecturer('Mike', 'Brown')
lecturer2.grades = {'Python': [10, 9, 10]}

print(f"student1 < student2: {student1 < student2}")
print(f"lecturer1 < lecturer2: {lecturer1 < lecturer2}")

print("\n4. Тест функций для подсчета средних оценок:")
students_list = [student1, student2]
lecturers_list = [lecturer1, lecturer2]

average_hw = average_hw_grade_for_course(students_list, 'Python')
average_lecture = average_lecture_grade_for_course(lecturers_list, 'Python')

print(f"Средняя оценка за домашние задания по курсу Python: {average_hw:.1f}")
print(f"Средняя оценка за лекции по курсу Python: {average_lecture:.1f}")
# Out:
# === Тестовая часть ===
# 1. Тест базового функционала:
# Оценки студента: {'Python': [9, 10, 8]}
# Оценки лектора: {'Python': [9, 10, 8]}
#
# 2. Тест магических методов __str__:
# Студент:
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.0
# Курсы в процессе изучения: Python, Git
# Завершенные курсы:
#
# Лектор:
# Имя: John
# Фамилия: Doe
# Средняя оценка за лекции: 9.0
#
# Проверяющий:
# Имя: Some
# Фамилия: Buddy
#
# 3. Тест сравнения объектов:
# student1 < student2: True
# lecturer1 < lecturer2: True
#
# 4. Тест функций для подсчета средних оценок:
# Средняя оценка за домашние задания по курсу Python: 8.8
# Средняя оценка за лекции по курсу Python: 9.0

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
# Ваш код

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
print("\n2. Тест магических методов __str__:")
print("Студент:")
print(best_student)
print("\nЛектор:")
print(cool_lecturer)
print("\nПроверяющий:")
print(cool_reviewer)
# Out:
# 2. Тест магических методов __str__:
# Студент:
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.0
# Курсы в процессе изучения: Python, Git
# Завершенные курсы:
#
# Лектор:
# Имя: John
# Фамилия: Doe
# Средняя оценка за лекции: 9.0
#
# Проверяющий:
# Имя: Some
# Фамилия: Buddy

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if (isinstance(lecturer, Lecturer) and
            course in lecturer.courses_attached and
            course in self.courses_in_progress and
            1 <= grade <= 10):
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else "нет"
        finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else "нет"
        avg_grade = self.average_grade()
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress_str}\n"
                f"Завершенные курсы: {finished_courses_str}")

    def __lt__(self, other):
        """Меньше - сравнение по средней оценке"""
        if not isinstance(other, Student):
            return NotImplemented
        return self.average_grade() < other.average_grade()

    def __le__(self, other):
        """Меньше или равно - сравнение по средней оценке"""
        if not isinstance(other, Student):
            return NotImplemented
        return self.average_grade() <= other.average_grade()

    def __eq__(self, other):
        """Равенство - сравнение по имени, фамилии и средней оценке"""
        if not isinstance(other, Student):
            return False
        return (self.name == other.name and
                self.surname == other.surname and
                self.average_grade() == other.average_grade())

    def __len__(self):
        """Возвращает общее количество полученных оценок"""
        total_grades = 0
        for grades_list in self.grades.values():
            total_grades += len(grades_list)
        return total_grades

    def __contains__(self, course_name):
        """Проверяет, изучает ли студент курс"""
        return course_name in self.courses_in_progress or course_name in self.finished_courses


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __eq__(self, other):
        """Равенство преподавателей - по имени и фамилии"""
        if not isinstance(other, Mentor):
            return False
        return self.name == other.name and self.surname == other.surname


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {avg_grade:.1f}"

    def __lt__(self, other):
        """Меньше - сравнение по средней оценке за лекции"""
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.average_grade() < other.average_grade()

    def __le__(self, other):
        """Меньше или равно - сравнение по средней оценке"""
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.average_grade() <= other.average_grade()

    def __len__(self):
        """Возвращает количество курсов, которые ведет лектор"""
        return len(self.courses_attached)

    def __getitem__(self, course_name):
        """Возвращает оценки по конкретному курсу"""
        return self.grades.get(course_name, [])

    def __call__(self):
        """Возвращает общее количество оценок у лектора"""
        total_grades = 0
        for grades_list in self.grades.values():
            total_grades += len(grades_list)
        return total_grades


class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)

    def rate_hw(self, student, course, grade):
        if (isinstance(student, Student) and
            course in self.courses_attached and
            course in student.courses_in_progress and
            1 <= grade <= 10):
            if course in student.grades:
                student.grades[course].append(grade)
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __len__(self):
        """Возвращает количество закрепленных курсов"""
        return len(self.courses_attached)

    def __contains__(self, course_name):
        """Проверяет, прикреплен ли проверяющий к курсу"""
        return course_name in self.courses_attached

    def __call__(self, student, course):
        """Возвращает среднюю оценку студента по конкретному курсу"""
        if course in student.grades:
            return sum(student.grades[course]) / len(student.grades[course])
        return 0


# Функции для подсчета средних оценок
def average_hw_grade_for_course(students, course_name):
    total_grades = []
    for student in students:
        if course_name in student.grades:
            total_grades.extend(student.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0


def average_lecture_grade_for_course(lecturers, course_name):
    total_grades = []
    for lecturer in lecturers:
        if course_name in lecturer.grades:
            total_grades.extend(lecturer.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if (isinstance(lecturer, Lecturer) and
            course in lecturer.courses_attached and
            course in self.courses_in_progress and
            1 <= grade <= 10):
            if course in lecturer.grades:
                lecturer.grades[course].append(grade)
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        courses_in_progress_str = ', '.join(self.courses_in_progress) if self.courses_in_progress else "нет"
        finished_courses_str = ', '.join(self.finished_courses) if self.finished_courses else "нет"
        avg_grade = self.average_grade()
        return (f"Имя: {self.name}\n"
                f"Фамилия: {self.surname}\n"
                f"Средняя оценка за домашние задания: {avg_grade:.1f}\n"
                f"Курсы в процессе изучения: {courses_in_progress_str}\n"
                f"Завершенные курсы: {finished_courses_str}")

    def __lt__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.average_grade() < other.average_grade()

    def __le__(self, other):
        if not isinstance(other, Student):
            return NotImplemented
        return self.average_grade() <= other.average_grade()

    def __eq__(self, other):
        if not isinstance(other, Student):
            return False
        return (self.name == other.name and
                self.surname == other.surname and
                self.average_grade() == other.average_grade())

    def __len__(self):
        total_grades = 0
        for grades_list in self.grades.values():
            total_grades += len(grades_list)
        return total_grades

    def __contains__(self, course_name):
        return course_name in self.courses_in_progress or course_name in self.finished_courses


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def __eq__(self, other):
        if not isinstance(other, Mentor):
            return False
        return self.name == other.name and self.surname == other.surname


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def average_grade(self):
        all_grades = []
        for grades_list in self.grades.values():
            all_grades.extend(grades_list)
        return sum(all_grades) / len(all_grades) if all_grades else 0

    def __str__(self):
        avg_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {avg_grade:.1f}"

    def __lt__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.average_grade() < other.average_grade()

    def __le__(self, other):
        if not isinstance(other, Lecturer):
            return NotImplemented
        return self.average_grade() <= other.average_grade()

    def __len__(self):
        return len(self.courses_attached)

    def __getitem__(self, course_name):
        return self.grades.get(course_name, [])

    def __call__(self):
        total_grades = 0
        for grades_list in self.grades.values():
            total_grades += len(grades_list)
        return total_grades


class Reviewer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)

    def rate_hw(self, student, course, grade):
        if (isinstance(student, Student) and
            course in self.courses_attached and
            course in student.courses_in_progress and
            1 <= grade <= 10):
            if course in student.grades:
                student.grades[course].append(grade)
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"

    def __len__(self):
        return len(self.courses_attached)

    def __contains__(self, course_name):
        return course_name in self.courses_attached

    def __call__(self, student, course):
        if course in student.grades:
            return sum(student.grades[course]) / len(student.grades[course])
        return 0


# Функция для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса
def average_hw_grade_for_course(students, course_name):
    """
    Подсчитывает среднюю оценку за домашние задания по всем студентам в рамках конкретного курса

    Args:
        students (list): Список объектов Student
        course_name (str): Название курса

    Returns:
        float: Средняя оценка за домашние задания по курсу
    """
    total_grades = []
    for student in students:
        if course_name in student.grades:
            total_grades.extend(student.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0


# Функция для подсчета средней оценки за лекции всех лекторов в рамках курса
def average_lecture_grade_for_course(lecturers, course_name):
    """
    Подсчитывает среднюю оценку за лекции всех лекторов в рамках курса

    Args:
        lecturers (list): Список объектов Lecturer
        course_name (str): Название курса

    Returns:
        float: Средняя оценка за лекции по курсу
    """
    total_grades = []
    for lecturer in lecturers:
        if course_name in lecturer.grades:
            total_grades.extend(lecturer.grades[course_name])
    return sum(total_grades) / len(total_grades) if total_grades else 0

# %%
# ============================================
# СОЗДАНИЕ ЭКЗЕМПЛЯРОВ КЛАССОВ (по 2 каждого)
# ============================================

print("=" * 60)
print("СОЗДАНИЕ ЭКЗЕМПЛЯРОВ КЛАССОВ")
print("=" * 60)

# Создаем 2 студентов
student1 = Student('Иван', 'Иванов', 'male')
student1.courses_in_progress = ['Python', 'JavaScript', 'Базы данных']
student1.finished_courses = ['Основы программирования', 'Алгоритмы']
student1.add_courses('Введение в математику')

student2 = Student('Мария', 'Петрова', 'female')
student2.courses_in_progress = ['Python', 'Java', 'Веб-разработка']
student2.finished_courses = ['Основы программирования', 'HTML/CSS']
student2.add_courses('Основы дизайна')

print("Студенты созданы:")
print(f"1. {student1.name} {student1.surname}")
print(f"2. {student2.name} {student2.surname}")

# Создаем 2 лекторов
lecturer1 = Lecturer('Алексей', 'Сидоров')
lecturer1.courses_attached = ['Python', 'JavaScript', 'Базы данных']

lecturer2 = Lecturer('Ольга', 'Кузнецова')
lecturer2.courses_attached = ['Python', 'Java', 'Веб-разработка']

print("\nЛекторы созданы:")
print(f"1. {lecturer1.name} {lecturer1.surname}")
print(f"2. {lecturer2.name} {lecturer2.surname}")

# Создаем 2 проверяющих
reviewer1 = Reviewer('Петр', 'Васильев')
reviewer1.courses_attached = ['Python', 'JavaScript', 'Базы данных']

reviewer2 = Reviewer('Елена', 'Смирнова')
reviewer2.courses_attached = ['Python', 'Java', 'Веб-разработка']

print("\nПроверяющие созданы:")
print(f"1. {reviewer1.name} {reviewer1.surname}")
print(f"2. {reviewer2.name} {reviewer2.surname}")

# ============================================
# ВЫСТАВЛЕНИЕ ОЦЕНОК И ВЗАИМОДЕЙСТВИЕ
# ============================================

print("\n" + "=" * 60)
print("ВЫСТАВЛЕНИЕ ОЦЕНОК И ВЗАИМОДЕЙСТВИЕ")
print("=" * 60)

# Reviewer1 выставляет оценки студенту1
print("\n1. Reviewer1 выставляет оценки Student1:")
reviewer1.rate_hw(student1, 'Python', 9)
reviewer1.rate_hw(student1, 'Python', 10)
reviewer1.rate_hw(student1, 'JavaScript', 8)
reviewer1.rate_hw(student1, 'Базы данных', 9)
print(f"   Оценки Student1: {student1.grades}")

# Reviewer2 выставляет оценки студенту2
print("\n2. Reviewer2 выставляет оценки Student2:")
reviewer2.rate_hw(student2, 'Python', 10)
reviewer2.rate_hw(student2, 'Python', 9)
reviewer2.rate_hw(student2, 'Java', 8)
reviewer2.rate_hw(student2, 'Веб-разработка', 9)
print(f"   Оценки Student2: {student2.grades}")

# Student1 выставляет оценки лекторам
print("\n3. Student1 выставляет оценки лекторам:")
student1.rate_lecturer(lecturer1, 'Python', 9)
student1.rate_lecturer(lecturer1, 'JavaScript', 10)
student1.rate_lecturer(lecturer1, 'Базы данных', 8)

student1.rate_lecturer(lecturer2, 'Python', 8)
print(f"   Оценки Lecturer1: {lecturer1.grades}")
print(f"   Оценки Lecturer2: {lecturer2.grades}")

# Student2 выставляет оценки лекторам
print("\n4. Student2 выставляет оценки лекторам:")
student2.rate_lecturer(lecturer1, 'Python', 9)
student2.rate_lecturer(lecturer2, 'Python', 10)
student2.rate_lecturer(lecturer2, 'Java', 9)
student2.rate_lecturer(lecturer2, 'Веб-разработка', 8)
print(f"   Оценки Lecturer1: {lecturer1.grades}")
print(f"   Оценки Lecturer2: {lecturer2.grades}")

# ============================================
# ВЫЗОВ ВСЕХ СОЗДАННЫХ МЕТОДОВ
# ============================================

print("\n" + "=" * 60)
print("ВЫЗОВ ВСЕХ СОЗДАННЫХ МЕТОДОВ")
print("=" * 60)

print("\n1. Методы Student:")
print("Student1.__str__():")
print(student1)
print(f"\nStudent1.average_grade(): {student1.average_grade():.2f}")
print(f"Student1.__len__(): {len(student1)}")
print(f"'Python' in Student1: {'Python' in student1}")
print(f"'C++' in Student1: {'C++' in student1}")

print("\n2. Методы Lecturer:")
print("Lecturer1.__str__():")
print(lecturer1)
print(f"\nLecturer1.average_grade(): {lecturer1.average_grade():.2f}")
print(f"Lecturer1.__len__(): {len(lecturer1)} (количество курсов)")
print(f"Lecturer1.__call__(): {lecturer1()} (общее количество оценок)")
print(f"Lecturer1['Python']: {lecturer1['Python']}")

print("\n3. Методы Reviewer:")
print("Reviewer1.__str__():")
print(reviewer1)
print(f"\nReviewer1.__len__(): {len(reviewer1)} (количество курсов)")
print(f"'Python' in Reviewer1: {'Python' in reviewer1}")
print(f"Reviewer1(student1, 'Python'): {reviewer1(student1, 'Python'):.2f}")

print("\n4. Сравнение объектов:")
print(f"student1 < student2: {student1 < student2}")
print(f"student1 <= student2: {student1 <= student2}")
print(f"lecturer1 < lecturer2: {lecturer1 < lecturer2}")
print(f"lecturer1 <= lecturer2: {lecturer1 <= lecturer2}")
print(f"student1 == student2: {student1 == student2}")
print(f"reviewer1 == reviewer2: {reviewer1 == reviewer2}")

# ============================================
# ИСПОЛЬЗОВАНИЕ ФУНКЦИЙ
# ============================================

print("\n" + "=" * 60)
print("ИСПОЛЬЗОВАНИЕ ФУНКЦИЙ ДЛЯ ПОДСЧЕТА СРЕДНИХ ОЦЕНОК")
print("=" * 60)

# Создаем списки для функций
students_list = [student1, student2]
lecturers_list = [lecturer1, lecturer2]

print("\n1. Средняя оценка за домашние задания по курсам:")
python_avg_hw = average_hw_grade_for_course(students_list, 'Python')
javascript_avg_hw = average_hw_grade_for_course(students_list, 'JavaScript')
java_avg_hw = average_hw_grade_for_course(students_list, 'Java')

print(f"   По курсу 'Python': {python_avg_hw:.2f}")
print(f"   По курсу 'JavaScript': {javascript_avg_hw:.2f}")
print(f"   По курсу 'Java': {java_avg_hw:.2f}")

print("\n2. Средняя оценка за лекции по курсам:")
python_avg_lecture = average_lecture_grade_for_course(lecturers_list, 'Python')
javascript_avg_lecture = average_lecture_grade_for_course(lecturers_list, 'JavaScript')
java_avg_lecture = average_lecture_grade_for_course(lecturers_list, 'Java')

print(f"   По курсу 'Python': {python_avg_lecture:.2f}")
print(f"   По курсу 'JavaScript': {javascript_avg_lecture:.2f}")
print(f"   По курсу 'Java': {java_avg_lecture:.2f}")
# Out:
# ...
# СОЗДАНИЕ ЭКЗЕМПЛЯРОВ КЛАССОВ
# ...
# Студенты созданы:
# 1. Иван Иванов
# 2. Мария Петрова
#
# Лекторы созданы:
# 1. Алексей Сидоров
# 2. Ольга Кузнецова
#
# Проверяющие созданы:
# 1. Петр Васильев
# 2. Елена Смирнова
#
# ...
# ВЫСТАВЛЕНИЕ ОЦЕНОК И ВЗАИМОДЕЙСТВИЕ
# ...
#
# 1. Reviewer1 выставляет оценки Student1:
#    Оценки Student1: {'Python': [9, 10], 'JavaScript': [8], 'Базы данных': [9]}
#
# 2. Reviewer2 выставляет оценки Student2:
#    Оценки Student2: {'Python': [10, 9], 'Java': [8], 'Веб-разработка': [9]}
#
# 3. Student1 выставляет оценки лекторам:
#    Оценки Lecturer1: {'Python': [9], 'JavaScript': [10], 'Базы данных': [8]}
#    Оценки Lecturer2: {'Python': [8]}
#
# 4. Student2 выставляет оценки лекторам:
#    Оценки Lecturer1: {'Python': [9, 9], 'JavaScript': [10], 'Базы данных': [8]}
#    Оценки Lecturer2: {'Python': [8, 10], 'Java': [9], 'Веб-разработка': [8]}
#
# ...
# ВЫЗОВ ВСЕХ СОЗДАННЫХ МЕТОДОВ
# ...
#
# 1. Методы Student:
# Student1.__str__():
# Имя: Иван
# Фамилия: Иванов
# ...

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
# Ваш код

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2014893486.py in <cell line: 0>()
#       1 # Создание дробей
# ----> 2 f1 = Fraction(3, 4)
#       3 f2 = Fraction(5, 6)
#       4
#       5 # Сложение дробей
#
# NameError: name 'Fraction' is not defined
